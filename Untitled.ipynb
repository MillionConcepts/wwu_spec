# %%
import numpy as np
from numpy.random import default_rng
import pandas as pd

# %%
r = default_rng()
spect = r.uniform(size=3000)
spect = pd.Series(spect)

# %%
# %%time
spect1 = (spect * 10 / 15 + 4)
spect1str = spect1.astype("str")
"M" + "L".join(list(spect1str.values))
# Out:
# CPU times: user 3.09 ms, sys: 15 µs, total: 3.1 ms
# Wall time: 3.07 ms
# ...
